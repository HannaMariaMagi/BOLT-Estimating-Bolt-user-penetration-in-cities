# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files
uploaded = files.upload()

import io
andmed = pd.read_csv(io.BytesIO(uploaded['Tartu_April_2019_UT_students - Tartu_April_2019_UT_students.csv']))
# Out:
#      <input type="file" id="files-cfb6ec25-d043-47f5-8fa3-f33a3a454d60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfb6ec25-d043-47f5-8fa3-f33a3a454d60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Tartu_April_2019_UT_students - Tartu_April_2019_UT_students.csv to Tartu_April_2019_UT_students - Tartu_April_2019_UT_students (2).csv

# %%
andmed.head()
# Out:
#    Unnamed: 0  pickup_lat  ...  work_address_lng  new_id
# 0           0      58.390  ...               NaN       0
# 1           1      58.384  ...               NaN       1
# 2           2      58.349  ...             26.40       2
# 3           3      58.382  ...               NaN       3
# 4           4      58.384  ...             26.67       4
#
# [5 rows x 14 columns]

# %%
len(andmed.new_id.unique().tolist())
# Out:
# 17447

# %%
andmedHomeAadress = andmed[leidubHomeAadress]
andmedHomeAadress.shape
# Out:
# (65102, 14)

# %%
andmed_kodu_aadressiga = andmed[andmed.home_address_lat.notnull()]
andmed_kodu_aadressiga.shape
# Out:
# (38682, 14)

# %%
#kodu aadressiga kasutajate koguarv
len(andmed_kodu_aadressiga.new_id.unique().tolist())
# Out:
# 9016

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import io


from google.colab import files
uploade = files.upload()
andmed_linnaosa = pd.read_csv(io.BytesIO(uploade['Bolt_data_districts - Bolt_data_districts.csv']), sep = ';')
# Out:
#      <input type="file" id="files-fdf26c71-618b-4b7f-90ed-e92f928b0e6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdf26c71-618b-4b7f-90ed-e92f928b0e6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
andmed_linnaosa.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...  destination_district work_district
# 0           0             0  ...             Kesklinna           NaN
# 1           1             1  ...       Raadi-Kruusamäe           NaN
# 2           2             2  ...               Veeriku           NaN
# 3           3             3  ...             Annelinna           NaN
# 4           4             4  ...               Veeriku           NaN
#
# [5 rows x 19 columns]

# %%
andmed_linnaosa["home_district"].value_counts()
# Out:
# Annelinna               5053
# Karlova                 3508
# Kesklinna               3487
# Ülejõe                  2982
# Tammelinna              1734
# Veeriku                 1442
# Raadi-Kruusamäe         1293
# Vaksali                 1278
# Ropka                   1030
# Tähtvere                 944
# Jaamamõisa               936
# Supilinna                880
# Ropka tööstuse           605
# Ihaste                   596
# Ränilinna                484
# Variku                   451
# Endine Tähtvere vald     301
# Maarjamõisa              292
# Name: home_district, dtype: int64

# %%
andmed_linnaosa.shape
# Out:
# (65102, 19)

# %%
unikaalsed_kasutajad = andmed_linnaosa.drop_duplicates(subset="new_id")
unikaalsed_kasutajad["home_district"].value_counts()
# Out:
# Annelinna               980
# Karlova                 650
# Kesklinna               603
# Ülejõe                  581
# Tammelinna              399
# Veeriku                 277
# Raadi-Kruusamäe         271
# Vaksali                 233
# Tähtvere                215
# Ropka                   207
# Jaamamõisa              173
# Ihaste                  159
# Supilinna               148
# Ropka tööstuse          115
# Variku                  102
# Ränilinna               101
# Endine Tähtvere vald     81
# Maarjamõisa              52
# Name: home_district, dtype: int64

# %%
unikaalsed_kasutajad.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b88dedd5169d> in <module>()
# ----> 1 unikaalsed_kasutajad.shape
#
# NameError: name 'unikaalsed_kasutajad' is not defined

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import io


from google.colab import files
upload = files.upload()
andmed_linnaosa_ennustustega = pd.read_csv(io.BytesIO(upload['Bolt_data_predicted_districts.csv']))
# Out:
#      <input type="file" id="files-9d56dd2c-3b4d-4c5c-877a-d440619bd82b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d56dd2c-3b4d-4c5c-877a-d440619bd82b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bolt_data_predicted_districts.csv to Bolt_data_predicted_districts.csv

# %%
andmed_linnaosa_ennustustega.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...  pred_home_district_dest  pred_home_district_pick
# 0           0             0  ...                      NaN                      NaN
# 1           1             1  ...                      NaN                      NaN
# 2           2             2  ...                      NaN                      NaN
# 3           3             3  ...                      NaN                      NaN
# 4           4             4  ...                      NaN                      NaN
#
# [5 rows x 27 columns]

# %%
unikaalsed_kasutajad_ennustustega = andmed_linnaosa_ennustustega.drop_duplicates(subset="new_id")
unikaalsed_kasutajad_ennustustega["pred_home_district_pick"].value_counts()
# Out:
# Annelinna               91
# Ülejõe                  89
# Tammelinna              69
# Karlova                 68
# Raadi-Kruusamäe         42
# Kesklinna               40
# Tähtvere                34
# Ihaste                  31
# Ropka                   28
# Veeriku                 27
# Jaamamõisa              20
# Vaksali                 20
# Supilinna               20
# Variku                  16
# Endine Tähtvere vald    10
# Ränilinna                5
# Ropka tööstuse           3
# Name: pred_home_district_pick, dtype: int64
